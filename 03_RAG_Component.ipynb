# %% [markdown]
# ## Character Text Splitter"""

# %%
 from langchain_groq import ChatGroq
llamaChatModel = ChatGroq( groq_api_key="" , model="llama-3.3-70b-versatile")

# %%
#Txt data loading

from langchain_community.document_loaders import TextLoader

loader = TextLoader("data/loda.txt", encoding="utf-8")
documents = loader.load()
print(documents)
# Out:
# [Document(metadata={'source': 'data/loda.txt'}, page_content='Breaking News: Global Climate Summit 2025 Achieves Historic Agreement\nIn a landmark development at the International Climate Conference in Geneva today, 195 nations have unanimously agreed to accelerate\n carbon reduction targets. The groundbreaking "Geneva Protocol" commits countries to achieve net-zero emissions by 2040, five \n years earlier than previously planned. The agreement includes unprecedented financial commitments from developed nations, pledging \n $500 billion annually to support renewable energy transitions in developing countries.\nChina and the United States, the world\'s largest carbon emitters, have announced joint initiatives to phase out coal power plants by\n 2030. The summit also introduced innovative carbon capture technologies, with pilot projects launching in 20 major cities worldwide.\n Environmental experts are calling this the most significant climate action since the Paris Agreement, marking
# ...

# %%
from langchain_text_splitters import CharacterTextSplitter

text_splitter = CharacterTextSplitter(
    separator="\n\n",
    chunk_size=2652,
    chunk_overlap=200,
    length_function=len,
    is_separator_regex=False,
)

# %%
from langchain_community.document_loaders import WikipediaLoader
loader = WikipediaLoader(query="Telsa", load_max_docs=2)
loaded_data = loader.load()[0].page_content
# Out:
# /Users/ajeettiwari/Documents/AAIEE/LLM/llmapp/lib/python3.9/site-packages/wikipedia/wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file /Users/ajeettiwari/Documents/AAIEE/LLM/llmapp/lib/python3.9/site-packages/wikipedia/wikipedia.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')

# %%
texts = text_splitter.create_documents([loaded_data])

# %% [markdown]
# Recursive Text Spliplitter"""

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=2652,
    chunk_overlap=200,
)
texts = text_splitter.split_text(loaded_data)

# %%
texts
# Out:
# ["Tesla, Inc. (  TESS-lə or  TEZ-lə) is an American multinational automotive and clean energy company. Headquartered in Austin, Texas, it designs, manufactures and sells battery electric vehicles (BEVs), stationary battery energy storage devices from home to grid-scale, solar panels and solar shingles, and related products and services.\nTesla was incorporated in July 2003 by Martin Eberhard and Marc Tarpenning as Tesla Motors. Its name is a tribute to inventor and electrical engineer Nikola Tesla. In February 2004, Elon Musk led Tesla's first funding round and became the company's chairman; in 2008, he was named chief executive officer. In 2008, the company began production of its first car model, the Roadster sports car, followed by the Model S sedan in 2012, the Model X SUV in 2015, the Model 3 sedan in 2017, the Model Y crossover in 2020, the Tesla Semi truck in 2022 and the Cybertruck pickup truck in 2023.\nTesla is one of the world's most valuable companies in terms of market c
# ...

# %%
import os
from dotenv import load_dotenv, find_dotenv

env_path = find_dotenv()

if env_path:
    with open(env_path) as f:
        

load_dotenv(env_path)
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
# Out:
#   Cell In[4], line 10
#     load_dotenv(env_path)
#                          ^
# IndentationError: expected an indented block

# %%
from dotenv import load_dotenv
import os

load_dotenv(dotenv_path=".env", override=True)  # Override existing env variables
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

print(f"Loaded API Key: {OPENAI_API_KEY}")
# Out:
# Loaded API Key: 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

# %%
import os 
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
from langchain_openai import OpenAI


llmMODEL = OpenAI(api_key=OPENAI_API_KEY)
print(OPENAI_API_KEY)
# Out:
# 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

# %%
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings()

# %%
chunks_of_data = [
    "Hi, how are you?",
    "I'm fine, thank you. How can I help you today?",
    "I'm looking for some information on the latest AI developments.",
    "What's the latest news in the AI field?",
]

# %%
embeddings = embeddings.embed_documents(chunks_of_data)
print(embeddings)
# Out:
# [[-0.01355085987597704, 0.0018688172567635775, 0.0018471407238394022, -0.03381521627306938, -0.017502162605524063, 0.019149569794535637, -0.010993042029440403, -0.011736233718693256, -0.010633832775056362, -0.01793569140136242, 0.023794516921043396, 0.0018951385281980038, -0.00932705495506525, -0.01424450520426035, 0.006756850052624941, -0.019248662516474724, 0.024661574512720108, -0.01187867857515812, 0.02779536508023739, -0.016870448365807533, -0.02079697884619236, 0.0070665134117007256, 0.02163926139473915, -0.0024355007335543633, -0.005638966336846352, -0.0019462329801172018, 0.0230884850025177, -0.015532704070210457, 0.013104945421218872, -0.028885379433631897, 0.00821226742118597, 0.0019632645417004824, -0.011482310481369495, 0.0004002396308351308, 0.015991006046533585, -0.021602101624011993, 0.0008043500711210072, -0.008552896790206432, 0.022617798298597336, -0.010770085267722607, 0.023955542594194412, -0.0019648128654807806, 0.011339864693582058, -0.016313055530190468, -0.008
# ...

# %%
from langchain_community.document_loaders import TextLoader
from langchain_openai import OpenAIEmbeddings
from langchain_text_splitters import CharacterTextSplitter
from langchain_chroma import Chroma

# Load the document, split it into chunks, embed each chunk and load it into the vector store.
raw_documents = TextLoader("./data/loda.txt").load()
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
documents = text_splitter.split_documents(raw_documents)
vector_db = Chroma.from_documents(documents, OpenAIEmbeddings())

# %%
vector_db

# %%
question = "What is the capital of France?"

response = vector_db.similarity_search(question)

print(response[0].page_content)
# Out:
# Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# Breaking News: Global Climate Summit 2025 Achieves Historic Agreement
# In a landmark development at the International Climate Conference in Geneva today, 195 nations have unanimously agreed to accelerate
#  carbon reduction targets. The groundbreaking "Geneva Protocol" commits countries to achieve net-zero emissions by 2040, five
#  years earlier than previously planned. The agreement includes unprecedented financial commitments from developed nations, pledging
#  $500 billion annually to support renewable energy transitions in developing countries.
# China and the United States, the world's largest carbon emitters, have announced joint initiatives to phase out coal power plants by
#  2030. The summit also introduced innovative carbon capture technologies, with pilot projects launching in 20 major cities worldwide.
# ...

# %% [markdown]
# ## VectorStore as Retrivriever
#
# ## Find the embedding that best answers your question.

# %%
# from langchain_community.vectorstores FAISS

# from langchain_openai import OpenAIEmbeddings
# from langchain_text_splitters import CharacterTextSplitter

# loaded_documents = TextLoader("data/loda.txt").load()
# text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
# chunks_of_data = text_splitter.split_documents(loaded_documents)

# embeddings = OpenAIEmbeddings()
# vector_db = FAISS.from_documents(chunks_of_data, embeddings)
# Out:
#   Cell In[21], line 1
#     from langchain_community.vectorstores FAISS
#                                           ^
# SyntaxError: invalid syntax

# %%
vector_db

# %%
retriever = vector_db.as_retriever() #to understand which line it is referring to

# %%
response = retriever.invoke("What is the capital of France?")
response
# Out:
# Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# ...
